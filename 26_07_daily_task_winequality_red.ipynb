# %% [markdown]
# <a href="https://colab.research.google.com/github/Rijinputhiyonnan/ICT-daily-task-Rijin/blob/main/26_07_daily_task_winequality_red.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# heat map
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), annot=True,cmap="YlGnBu", vmin=-.2, vmax=.9, linewidth =0.5)
# Out:
# <Axes: >

# %%
# outlier
for i in df.columns:

  sns.boxplot(df[i])
  plt.title(i)
  plt.show()

# %%
for i in df.columns:
  sns.histplot(df[i])
  plt.title(i)
  plt.show()

# %%
y = df['quality']
x = df.drop('quality', axis = 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lireg = LinearRegression()
model = lireg.fit(x_train, y_train)
model
# Out:
# LinearRegression()

# %%
x_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 803             7.7              0.56         0.08            2.50      0.114
# 124             7.8              0.50         0.17            1.60      0.082
# 350            10.7              0.67         0.22            2.70      0.107
# 682             8.5              0.46         0.31            2.25      0.078
# 1326            6.7              0.46         0.24            1.70      0.077
# ...             ...               ...          ...             ...        ...
# 1565            6.7              0.67         0.02            1.90      0.061
# 327            10.3              0.44         0.50            4.50      0.107
# 254             7.1              0.60         0.00            1.80      0.074
# 322             7.8              0.62         0.05            2.30      0.079
# 1160           10.6              0.36         0.57            2.30      0.087
#
# ...

# %%
p=model.predict(x_test)
p
# Out:
# array([5.34360227, 5.06294956, 5.63333204, 5.45176186, 5.74570371,
#        5.27637941, 5.03060591, 5.14548634, 5.74793413, 5.71379639,
#        6.14292388, 5.25602325, 5.55746352, 5.25516748, 5.44918167,
#        6.50428691, 5.16155023, 5.58177831, 6.56354719, 5.31109369,
#        5.42314936, 5.19226562, 5.99245498, 6.40578182, 5.36515018,
#        5.42441564, 6.35376721, 5.37618609, 5.16180078, 6.16014475,
#        5.25888679, 5.538378  , 5.7525049 , 5.3863994 , 5.45667328,
#        5.02911082, 6.1905284 , 5.71266674, 5.63463533, 6.20179362,
#        5.50279355, 5.24191583, 6.16908347, 5.15779342, 5.85212953,
#        5.8169982 , 6.415135  , 5.57902528, 5.16752006, 5.57681837,
#        5.12302477, 5.08832659, 5.6067245 , 6.37829292, 4.96528844,
#        4.97488594, 6.03283966, 5.4259819 , 5.86156997, 5.26390122,
#        5.60706205, 5.97031204, 5.28379018, 5.32034058, 6.50607979,
#        5.41422594, 6.36327206, 5.25281218, 6.43657812, 5.30042793,
# ...

# %%
y_test.head()
# Out:
# 803     6
# 124     5
# 350     6
# 682     5
# 1326    6
# Name: quality, dtype: int64

# %%
from sklearn.metrics import mean_squared_error
print('mse = ', mean_squared_error(y_test, p))
# Out:
# mse =  0.3883017386868924

# %%
from sklearn.metrics import r2_score
r2_score(y_test, p)
# Out:
# 0.37228312008181075

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, p)
# Out:
# 0.4998799122925442
